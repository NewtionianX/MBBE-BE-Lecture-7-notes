# %% [markdown]
# # Lecture 7 Notes
#
# Intro To Scikit-learn

# %%
# !pip install pandas
# !pip install scikit-learn

# %%
from sklearn import datasets

# %%
iris = datasets.load_iris()

x = iris.data
y = iris.target

# %%
#look at data


#convert to data frame 

# we can pass in something called coloums for formatting

iris_df= pd.DataFrame(x), columns = iris.feature_names


# at the target (out) column
# we set a new index in a way
iris_df("target") = y

iris_df
# Out:
#   Cell In[34], line 8
#     iris_df= pd.DataFrame(x), columns = iris.feature_names
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
# split the data for tryin

# %% [markdown]
# # split the data for training

# %%
from sklearn_selection import train_test_split

# Way this works it gives us four outputs input and out and also the results from training


X_train, X_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state=42)

X_train

# we can also do X_train.shape

# %% [markdown]
# ### Train a Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
# if we hover over the model we can see attritubutes

model.fit(X_train,y_train)

#model fit is how you train your mode effectively

# %% [markdown]
# ### Make predictions on the test set

# %%
y_pred = model.predict(X_test)

y_pred

#so it should output the guess of what it is with the iris set it say 1,2,0 for the 3 different types of flowers

# %% [markdown]
# ### Evualate the Accuracy of test set predictions

# %%
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_test,y_pred)

acc

# %% [markdown]
# ### Splitting model data to test accurancy
